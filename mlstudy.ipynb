# %%
from mlstudy import MLStudy, MLUtils

# %%
# Load the study and the primary processing script
study=MLStudy(id='kAbvLJTOaT')
script=study.script('001_analysis');

# %%
# Load the results
A=script.result('K15/cluster_metrics.json')
cluster_metrics=MLUtils.loadJson(A)

TT=script.result('K15/templates.mda')
templates=MLUtils.loadMda(TT)

# %%
print(templates.shape)
# Out:
# (4, 200, 12)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
for k in range(templates.shape[2]):
    for m in range(4):
        plt.plot(np.arange(200),templates[m,:,k])
    plt.show()
